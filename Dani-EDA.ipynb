# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pyreadstat

# %%
df, meta = pyreadstat.read_sav("data/W1 Merged Data/Wave.1_Data/Japan/Japan v4.2.sav")
df.head()
# Out:
#    country  idnumber  level1  level3  grtokyo  grkansai  jcity  yrsurvey  \
# 0      1.0       0.0     3.0     2.0      2.0       2.0    5.0    2003.0
# 1      1.0       3.0     3.0     2.0      2.0       2.0    5.0    2003.0
# 2      1.0       4.0     3.0     2.0      2.0       2.0    5.0    2003.0
# 3      1.0       5.0     3.0     2.0      2.0       2.0    5.0    2003.0
# 4      1.0       6.0     3.0     2.0      2.0       2.0    5.0    2003.0
#
#    month   day  ...  q0971c  q0972a  q0972b  q0972c  q0973a  q0973b  q0973c  \
# 0    1.0  28.0  ...     NaN   640.0     NaN     NaN     NaN     NaN     NaN
# 1    2.0   2.0  ...     NaN   212.0     NaN     NaN   210.0   314.0     NaN
# 2    1.0  29.0  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3    2.0   2.0  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4    1.0  28.0  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#     c3   c2      w_jp
# 0  4.0  4.0  0.566428
# 1  2.0  2.0  0.778703
# ...

# %%
#df.rename(columns=(meta.column_names_to_labels), inplace =True)
df.head()
# Out:
#    country  idnumber  level1  level3  grtokyo  grkansai  jcity  yrsurvey  \
# 0      1.0       0.0     3.0     2.0      2.0       2.0    5.0    2003.0
# 1      1.0       3.0     3.0     2.0      2.0       2.0    5.0    2003.0
# 2      1.0       4.0     3.0     2.0      2.0       2.0    5.0    2003.0
# 3      1.0       5.0     3.0     2.0      2.0       2.0    5.0    2003.0
# 4      1.0       6.0     3.0     2.0      2.0       2.0    5.0    2003.0
#
#    month   day  ...  q0971c  q0972a  q0972b  q0972c  q0973a  q0973b  q0973c  \
# 0    1.0  28.0  ...     NaN   640.0     NaN     NaN     NaN     NaN     NaN
# 1    2.0   2.0  ...     NaN   212.0     NaN     NaN   210.0   314.0     NaN
# 2    1.0  29.0  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3    2.0   2.0  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4    1.0  28.0  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#     c3   c2      w_jp
# 0  4.0  4.0  0.566428
# 1  2.0  2.0  0.778703
# ...

# %%
meta.variable_value_labels
# Out:
# {'country': {1.0: 'Japan'},
#  'level3': {1.0: 'urban', 2.0: 'rural'},
#  'grtokyo': {1.0: 'yes, within', 2.0: 'no'},
#  'grkansai': {1.0: 'yes, within', 2.0: 'no'},
#  'jcity': {1.0: 'Metropolis (MT million)',
#   2.0: 'Cities MT 200T',
#   3.0: 'MT 100T',
#   4.0: 'LT 100T',
#   5.0: 'Towns & Villages'},
#  'yrsurvey': {2003.0: '2003'},
#  'month': {1.0: '1', 2.0: '2'},
#  'day': {1.0: '1',
#   2.0: '2',
#   3.0: '3',
#   4.0: '4',
#   22.0: '22',
#   23.0: '23',
#   24.0: '24',
#   25.0: '25',
#   26.0: '26',
#   27.0: '27',
#   28.0: '28',
#   29.0: '29',
#   30.0: '30',
#   31.0: '31'},
#  'time': {15.0: '15',
#   18.0: '18',
#   19.0: '19',
#   20.0: '20',
#   21.0: '21',
#   22.0: '22',
#   23.0: '23',
#   24.0: '24',
#   25.0: '25',
#   26.0: '26',
#   27.0: '27',
#   28.0: '28',
#   29.0: '29',
#   30.0: '30',
#   31.0: '31',
#   32.0: '32',
#   33.0: '33',
#   34.0: '34',
#   35.0: '35',
#   36.0: '36',
#   37.0: '37',
#   38.0: '38',
#   39.0: '39',
#   40.0: '40',
# ...

# %%
smalldf = df[["se002", 'se004', 'se005', 'se009', 'se003a', 'country', 'q007', 'q008', 'q009', 'q010', 'q006', 'q098', 'q128', 'q005', 'q027', 'q028', 'q105', 'q106', 'q121', 'q123', 'q127']]
smalldf
# Out:
#       se002  se004  se005  se009  se003a  country  q007  q008  q009  q010  \
# 0       2.0    1.0    8.0    NaN    59.0      1.0   3.0   2.0   2.0   2.0
# 1       2.0    1.0    7.0    NaN    59.0      1.0   4.0   2.0   NaN   NaN
# 2       2.0    3.0    2.0    1.0    73.0      1.0   NaN   NaN   NaN   NaN
# 3       2.0    6.0    8.0    NaN    25.0      1.0   3.0   2.0   2.0   2.0
# 4       1.0    1.0    6.0    2.0    88.0      1.0   3.0   NaN   NaN   NaN
# ...     ...    ...    ...    ...     ...      ...   ...   ...   ...   ...
# 1413    2.0    1.0    7.0    1.0    58.0      1.0   3.0   2.0   1.0   2.0
# 1414    1.0    1.0    NaN    1.0    70.0      1.0   3.0   3.0   3.0   3.0
# 1415    1.0    6.0    3.0    NaN    55.0      1.0   NaN   2.0   3.0   1.0
# 1416    1.0    6.0    9.0    2.0    45.0      1.0   3.0   3.0   2.0   2.0
# 1417    1.0    1.0    3.0    1.0    36.0      1.0   3.0   3.0   3.0   3.0
#
#       ...  q098  q128  q005  q027   q028  q105  q106  q121  q123  q127
# ...

# %%
merge_df, merge_meta = pyreadstat.read_sav("data/W1 Merged Data/Wave.1_Data/Merge/Wave1_20170906.sav")

# %%
merge_meta.variable_value_labels
# Out:
# {'country': {1.0: 'Japan',
#   2.0: 'Hong Kong',
#   3.0: 'Korea',
#   4.0: 'Mainland China',
#   5.0: 'Mongolia',
#   6.0: 'Philippines',
#   7.0: 'Taiwan',
#   8.0: 'Thailand'},
#  'level3': {1.0: 'urban', 2.0: 'rural', 3.0: 'no registration'},
#  'yrsurvey': {2001.0: '2001', 2002.0: '2002', 2003.0: '2003'},
#  'se002': {1.0: 'male', 2.0: 'female', 99.0: 'No Answer'},
#  'se003': {1.0: '18-19',
#   2.0: '20-24',
#   3.0: '25-29',
#   4.0: '30-34',
#   5.0: '35-39',
#   6.0: '40-44',
#   7.0: '45-49',
#   8.0: '50-54',
#   9.0: '55-59',
#   10.0: '60-70',
#   11.0: '71-75',
#   12.0: '76 & over',
#   99.0: 'No Answer'},
#  'se003a': {18.0: '18',
#   19.0: '19',
#   20.0: '20',
#   21.0: '21',
#   22.0: '22',
#   23.0: '23',
#   24.0: '24',
#   25.0: '25',
#   26.0: '26',
#   27.0: '27',
#   28.0: '28',
#   29.0: '29',
#   30.0: '30',
#   31.0: '31',
#   32.0: '32',
#   33.0: '33',
#   34.0: '34',
#   35.0: '35',
#   36.0: '36',
#   37.0: '37',
#   38.0: '38',
#   39.0: '39',
# ...

# %%
merge_df["country"].rename(meta.variable_value_labels)
merge_df.country.value_counts()
# Out:
# 4.0    3183
# 8.0    1546
# 3.0    1500
# 1.0    1418
# 7.0    1415
# 6.0    1200
# 5.0    1144
# 2.0     811
# Name: country, dtype: int64

# %%
merge_df.drop(columns= ["se004", "q007", "q008", "q009", "q010", "q010", "q006", "q098", "q128", "q005", "q027", "q028", "q105", "q121", "q123", "q127"], inplace=True)
merge_df
# Out:
#        country  idnumber  level3  yrsurvey  se002  se003  se003a  se004a  \
# 0          4.0       1.0     1.0    2002.0    1.0    5.0    38.0     1.0
# 1          4.0       2.0     1.0    2002.0    2.0   10.0    60.0     1.0
# 2          4.0       3.0     1.0    2002.0    2.0   10.0    69.0     1.0
# 3          4.0       4.0     1.0    2002.0    2.0    5.0    39.0     1.0
# 4          4.0       5.0     1.0    2002.0    1.0    7.0    48.0     1.0
# ...        ...       ...     ...       ...    ...    ...     ...     ...
# 12212      8.0    1542.0     2.0    2002.0    2.0    3.0    27.0     2.0
# 12213      8.0    1543.0     2.0    2002.0    1.0   10.0    70.0     1.0
# 12214      8.0    1544.0     2.0    2002.0    2.0    5.0    37.0     1.0
# 12215      8.0    1545.0     2.0    2002.0    2.0    9.0    58.0     1.0
# 12216      8.0    1546.0     2.0    2002.0    2.0    4.0    31.0     1.0
#
#        se005  se005a  ...  ir010e  w_jp  w_hk  w_kr      w_cn  w_mo  w_ph  \
# ...
